# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have curtailment data with availability bins
# This creates a visualization of curtailment share by availability bins

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Bar chart: Curtailment Share by Availability Bins
axes[0].bar(availability_bins, curtailment_share, color='steelblue', alpha=0.7, edgecolor='black')
axes[0].set_xlabel('Availability Bins (%)', fontsize=12)
axes[0].set_ylabel('Curtailment Share (%)', fontsize=12)
axes[0].set_title('Curtailment Share by Availability Bins', fontsize=13, fontweight='bold')
axes[0].grid(axis='y', alpha=0.3)

# Line chart: Trend of Curtailment Share
axes[1].plot(availability_bins, curtailment_share, marker='o', linewidth=2, markersize=8, color='darkred')
axes[1].set_xlabel('Availability Bins (%)', fontsize=12)
axes[1].set_ylabel('Curtailment Share (%)', fontsize=12)
axes[1].set_title('Curtailment Share Trend', fontsize=13, fontweight='bold')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       7 fig, axes = plt.subplots(1, 2, figsize=(14, 5))
#       9 # Bar chart: Curtailment Share by Availability Bins
# ---> 10 axes[0].bar(availability_bins, curtailment_share, color='steelblue', alpha=0.7, edgecolor='black')
#      11 axes[0].set_xlabel('Availability Bins (%)', fontsize=12)
#      12 axes[0].set_ylabel('Curtailment Share (%)', fontsize=12)
#
# NameError: name 'availability_bins' is not defined
